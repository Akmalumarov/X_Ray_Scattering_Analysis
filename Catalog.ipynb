# %%
# %run setup_workspace.py

# %%
scan_session(
    session_path=r'\\Synology\Data\2025\SC_5732',
    catalog_path=r"Experimet_Catalog.csv"
)
# Out:
# ...
# Scanning WAXS: 100%|█████████████████████████████████████████████████████████████████| 204/204 [00:04<00:00, 48.31it/s]
# Catalog updated: 372 experiments added to SC_5732
# Total entries in catalog: 94353

# %%
path = r'C:\Users\LabPCA\Desktop\X_Ray_Scattering_Analysis/Experimet_Catalog.csv'
df = pd.read_csv(path)
df.head()
# Out:
#        session                title keys  \
# 0  BM26 SC5736  Capillary_2mm_water  NaN
# 1  BM26 SC5736  Capillary_2mm_water  NaN
# 2  BM26 SC5736  PEG_PLA_11_pristine  NaN
# 3  BM26 SC5736  PEG_PLA_11_pristine  NaN
# 4  BM26 SC5736        PEG_PLA_8_bis  NaN
#
#                                            file_path file_type
# 0  \\Synology\Data\2024\BM26 SC5736\Capillary_2mm...   edf/dat
# 1  \\Synology\Data\2024\BM26 SC5736\Capillary_2mm...   edf/dat
# 2  \\Synology\Data\2024\BM26 SC5736\PEG_PLA_11_pr...   edf/dat
# 3  \\Synology\Data\2024\BM26 SC5736\PEG_PLA_11_pr...   edf/dat
# 4  \\Synology\Data\2024\BM26 SC5736\PEG_PLA_8_bis...   edf/dat

# %%
filtered_df = df[df['title'].str.contains('Oh', case=False, na=False) 
                 # & df['title'].str.contains('heat', case=False, na=False)
    ]

filtered_df
# Out:
#             session                             title keys  \
# 204    BM26_Feb2024         NOHPDMS_100perc_stretcher  NaN
# 205    BM26_Feb2024         NOHPDMS_100perc_stretcher  NaN
# 206    BM26_Feb2024  NOHPDMS_100perc_stretcher_repeat  NaN
# 207    BM26_Feb2024  NOHPDMS_100perc_stretcher_repeat  NaN
# 208    BM26_Feb2024                   NOHPDMS_100pers  NaN
# ...             ...                               ...  ...
# 90369        sc5665           NOH_NG_6_Melt_20ms_1_1m  NaN
# 90370        sc5665           NOH_NG_6_Melt_20ms_1_1m  NaN
# 90371        sc5665           NOH_NG_6_Melt_20ms_1_1m  NaN
# 90372        sc5665           NOH_NG_6_Melt_20ms_1_1m  NaN
# 90373        sc5665           NOH_NG_6_Melt_20ms_1_1m  NaN
#
#                                                file_path file_type
# 204    \\Synology\Data\2024\BM26_Feb2024\NOHPDMS_100p...   edf/dat
# 205    \\Synology\Data\2024\BM26_Feb2024\NOHPDMS_100p...   edf/dat
# ...

# %%
for title in filtered_df['title']:
    print(title)
# Out:
# NOHPDMS_100perc_stretcher
# NOHPDMS_100perc_stretcher
# NOHPDMS_100perc_stretcher_repeat
# NOHPDMS_100perc_stretcher_repeat
# NOHPDMS_100pers
# NOHPDMS_100pers
# NOHPDMS_90perc_stretcher
# NOHPDMS_90perc_stretcher
# NOHPDMS_90pers
# NOHPDMS_90pers
# NOH_0perc_hexane_Solution_1_25perc
# NOH_0perc_hexane_Solution_1_25perc
# NOH_0perc_hexane_Solution_2_5perc
# NOH_0perc_hexane_Solution_2_5perc
# NOH_0perc_hexane_second_Solution_0_6perc
# NOH_0perc_hexane_second_Solution_0_6perc
# NOH_100perc_hexane_Hexane_pure
# NOH_100perc_hexane_Hexane_pure
# NOH_100perc_hexane_Solution_1_25perc
# NOH_100perc_hexane_Solution_1_25perc
# NOH_100perc_hexane_Solution_2_5perc
# NOH_100perc_hexane_Solution_2_5perc
# NOH_100perc_hexane_second_Solution_0_6perc
# NOH_100perc_hexane_second_Solution_0_6perc
# NOH_100perc_melt_static_1_4m
# NOH_100perc_melt_static_1_4m
# NOH_50perc_melt_static_1_4m
# NOH_50perc_melt_static_1_4m
# NOH_80perc_melt_static_1_4m
# NOH_80perc_melt_static_1_4m
# ...
