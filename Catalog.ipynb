# %%
# %run setup_workspace.py

# %%
scan_session(
    session_path=r'\\Synology\Data\2026\SC5782',
    catalog_path=r"Experimet_Catalog.csv"
)
# Out:
# ...
# Scanning WAXS: 100%|████████████████████████████████████████████████████████████████| 234/234 [00:01<00:00, 140.63it/s]
# Catalog updated: 330 experiments added to SC5782
# Total entries in catalog: 12632
