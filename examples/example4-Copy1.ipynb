# %%
import numpy as np

x = np.linspace(-5,5,500)
y = np.exp(-x**2/10)
# В ячейке ноутбука

# %%
plot_pandas_GUI()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 plot_pandas_GUI()
#
# NameError: name 'plot_pandas_GUI' is not defined
