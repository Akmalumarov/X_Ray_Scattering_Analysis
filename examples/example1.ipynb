# %%
# %run ../setup_workspace.py
# Out:
# ✓ Рабочее пространство готово

# %%
# В любой ячейке после setup_workspace.py:

q = np.linspace(0.1, 3, 1000)
# Функции SAXS доступны сразу
I_mono = Monodisperse_spheres(q, scale=1.0, R=50, SLD_sphere=1.0, SLD_solvent=0.0, bkg=0.001)
I_poly = Polydisperse_spheres(q, scale=1.0, Ravg=50, p=0.1, bkg=0.001)

plt.plot(q, I_mono)
plt.semilogx()
plt.semilogy()
# Out:
# []

# %%
scan_session('/Users/akmalumarov/Desktop/X-Ray Analysis/Gelation_data/SC_5665', 
             "experiment_catalog.csv")
# Out:
# Catalog updated: 35 new experiments added

# %%
scan_session('/Users/akmalumarov/Desktop/X-Ray Analysis/PE Nikos Data/SC5711', 
             "experiment_catalog.csv")
# Out:
# Catalog updated: 20 new experiments added
