# %%
# %run ../setup_workspace.py
# Out:
# ✓ Рабочее пространство готово

# %%
exp1 = BM26_experiment('/Users/akmalumarov/Yandex.Disk.localized/Sergei_silk/Stretcher_Sergei_silk_RT_bis_0_5mm')
exp2 = BM26_experiment('/Users/akmalumarov/Yandex.Disk.localized/Sergei_silk/Stretcher_Sergei_silk_RT_bis_1_5mm')
exp3 = BM26_experiment('/Users/akmalumarov/Yandex.Disk.localized/Sergei_silk/Stretcher_Sergei_silk_RT_bis_2_0mm')

# %%
plt.figure(figsize=(4,4))

q, I1 = exp1.get_1d_SAXS()
#plt.plot(q, I1, label='empty')

q, I2 = exp2.get_1d_SAXS()
#plt.plot(q, I2, label='bisbis 2.0mm')

plt.plot(q, I2-I1, label='sub')

plt.legend()

#print(q[np.argmax(I)])

plt.ylabel('I / a.u.')
plt.xlabel('q / nm')
plt.xlim(1, 35)
plt.ylim(0, 1200)
#plt.semilogx()
#plt.semilogy()
# Out:
# (0.0, 1200.0)
