# %% [markdown]
# # Libraries & Set up

# %%
# %run ../setup_workspace.py
# Out:
# ✓ Рабочее пространство готово

# %% [markdown]
# # Data

# %%
Some_Experiment = BM26_experiment('/Users/akmalumarov/Desktop/X-Ray Analysis/PE Nikos Data/SC5711/PE_Nikos/PE_Nikos_NG_82B')
# ...
# ...
# ...

# %% [markdown]
# # Functions

# %%
def linear(x, k, b):
    return k * x + b

# %% [markdown]
# # Analysis

# %%
q, I = Some_Experiment.get_1d_SAXS()
plt.plot(q, I)

p, cov = curve_fit(linear, q, I)


plt.semilogx()
plt.semilogy()
plt.xlim(0.035, 2.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 4
#       1 q, I = Some_Experiment.get_1d_SAXS()
#       2 plt.plot(q, I)
# ----> 4 p, cov = curve_fit(linear, q, I)
#       7 plt.semilogx()
#       8 plt.semilogy()
#
# NameError: name 'curve_fit' is not defined
