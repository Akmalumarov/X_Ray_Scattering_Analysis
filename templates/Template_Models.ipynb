# %%
# %run ../setup_workspace.py
# Out:
# ✗ Import error: cannot import name 'list_models' from 'tools.models_tools.utils' (/Users/akmalumarov/Desktop/X_Ray_Scattering_Analysis/tools/models_tools/utils.py)
# Run: pip install -e .

# %%
Peak = Gaussian(amplitude=10, center=15, sigma=3) 
Bkg = PowerLaw(1, 1)

model = Peak + Bkg

y = model(x) 

plt.plot(x, y)

components = decompose(Peak + Bkg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 Peak = Gaussian(amplitude=10, center=15, sigma=3)
#       2 Bkg = PowerLaw(1, 1)
#       4 model = Peak + Bkg
#
# NameError: name 'Gaussian' is not defined

# %%
plt.figure(figsize=(10, 6))
plt.plot(x, y, 'k-', linewidth=3, label='Total model')

# Customize plot
plt.xlabel('x', fontsize=12)
plt.ylabel('y', fontsize=12)
plt.title('Composite Model: Gaussian + PowerLaw', fontsize=14)
plt.legend(fontsize=10)
plt.grid(True, alpha=0.3)

plt.show()

# Print model info
print("Model created successfully")
print(f"Model type: {model.__class__.__name__}")
print(f"Number of components: {len(model.models) if hasattr(model, 'models') else 1}")
# Out:
# Model created successfully
# Model type: CompositeModel
# Number of components: 2
