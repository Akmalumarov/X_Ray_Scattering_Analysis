# %% [markdown]
# # Libraries & Set up

# %%
# %run ../setup_workspace.py
# Out:
# ✓ Workspace ready

# %% [markdown]
# # Data

# %%
Some_Experiment = BM26_experiment(r"E:\PEG_g_PLA Nikos 2025\SC5732\Brushes_PEG_PLA\Brushes_PEG_PLA_PA304_97_3_600DP_firstheat_175C_and_back")
# ...
# ...
# ...

# %% [markdown]
# # Functions

# %%
def linear(x, k, b):
    return k * x + b

# %% [markdown]
# # Analysis

# %%
q, I = Some_Experiment.get_1d_SAXS()


plt.figure(figsize=(5,5))
plt.plot(q, I)

p, cov = curve_fit(linear, q, I)

plt.semilogx()
plt.semilogy()
plt.xlim(0.1, 3)
# Out:
# (0.1, 3)
