# %% [markdown]
# # Set up

# %%
# %run ../../../setup_workspace.py # ../ means level up

# %% [markdown]
# # Data

# %% [markdown]
# #### SC5782

# %%
plt.rcParams['font.family'] = 'Arial'
plt.rcParams['font.size'] = 12
plt.rcParams['axes.linewidth'] = 2
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.rcParams['xtick.major.width'] = 2
plt.rcParams['ytick.major.width'] = 2
plt.rcParams['xtick.major.size'] = 6
plt.rcParams['ytick.major.size'] = 6
from matplotlib.ticker import ScalarFormatter

# %%
fig, ax = plt.subplots(1,1, figsize=(3,6))
lines = 3
path = r"\\Synology\Data\2026\SC5782\RAW_DATA\PVDF\PVDF_PVDF_1"

Exp = BM26_experiment(path)
q, I = Exp.get_1d_SAXS()
plt.loglog(q, I, color='#f29222', linewidth=lines)


path = r"\\Synology\Data\2026\SC5782\RAW_DATA\PVDF\PVDF_PVDF_LiTFSI_2"

Exp = BM26_experiment(path)
q, I = Exp.get_1d_SAXS()
plt.loglog(q, I * 4, color='#a1c65d', linewidth=lines)


path = r"\\Synology\Data\2026\SC5782\RAW_DATA\PVDF\PVDF_PVDF_LiTFSI_3"

Exp = BM26_experiment(path)
q, I = Exp.get_1d_SAXS()
plt.loglog(q, I * 7, color='#0cb2af', linewidth=lines)

path = r"\\Synology\Data\2026\SC5782\RAW_DATA\PVDF\PVDF_PVDF_PDAD_LiTFSZ_5"

Exp = BM26_experiment(path)
q, I = Exp.get_1d_SAXS()
plt.loglog(q, I * 50, color='#936fac', linewidth=lines)


path = r"\\Synology\Data\2026\SC5782\RAW_DATA\PVDF\PVDF_PVDF_PDAD_6"

Exp = BM26_experiment(path)
q, I = Exp.get_1d_SAXS()
plt.loglog(q, I * 100, color='#fac723', linewidth=lines)


path = r"\\Synology\Data\2026\SC5782\RAW_DATA\PVDF\PVDF_PVDF_PDADMAT_4"

Exp = BM26_experiment(path)
q, I = Exp.get_1d_SAXS()
plt.loglog(q, I * 250, color='#e95e50', linewidth=lines)

plt.xlim(0.15, 3)

plt.xlabel('q (nm$^{-1}$)', fontname='Arial', fontsize=20)  # ← Markdown для степени
plt.ylabel('I (a.u.)', fontname='Arial', fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=15)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(2)
ax.set_position([0.1, 0.15, 0.75, 0.7])
ax.tick_params(axis="both", which='major', direction="in", width=2, length=4, labelsize=16)
ax.tick_params(axis='both', which='minor', width=2, length=2)

ax.xaxis.set_major_formatter(ScalarFormatter())
ax.set_xticks([0.2, 1,
              ])

plt.savefig(r'E:\PVDF_Sergeev\Figures\Fig_SAXS.png', dpi=300, bbox_inches='tight', transparent=True)

# %%
fig, ax = plt.subplots(1,1, figsize=(4,6))
lines = 3
path = r"\\Synology\Data\2026\SC5782\RAW_DATA\PVDF\PVDF_PVDF_1"

Exp = BM26_experiment(path)
q, I = Exp.get_1d_WAXS()
plt.plot(q, I*1e4, color='#f29222', linewidth=lines, label='PVDF_PVDF_1')


path = r"\\Synology\Data\2026\SC5782\RAW_DATA\PVDF\PVDF_PVDF_LiTFSI_2"

Exp = BM26_experiment(path)
q, I = Exp.get_1d_WAXS()
plt.plot(q, I*1e4 + 5 , color='#a1c65d', linewidth=lines, label='PVDF_PVDF_LiTFSI_2')


path = r"\\Synology\Data\2026\SC5782\RAW_DATA\PVDF\PVDF_PVDF_LiTFSI_3"

Exp = BM26_experiment(path)
q, I = Exp.get_1d_WAXS()
plt.plot(q, I*1e4 + 10, color='#0cb2af', linewidth=lines, label='PVDF_PVDF_LiTFSI_3')

path = r"\\Synology\Data\2026\SC5782\RAW_DATA\PVDF\PVDF_PVDF_PDAD_LiTFSZ_5"

Exp = BM26_experiment(path)
q, I = Exp.get_1d_WAXS()
plt.plot(q, I*1e4 + 15, color='#936fac', linewidth=lines, label='PVDF_PVDF_PDAD_LiTFSZ_5')


path = r"\\Synology\Data\2026\SC5782\RAW_DATA\PVDF\PVDF_PVDF_PDAD_6"

Exp = BM26_experiment(path)
q, I = Exp.get_1d_WAXS()
plt.plot(q, I*1e4 + 20, color='#fac723', linewidth=lines, label='PVDF_PVDF_PDAD_6')


path = r"\\Synology\Data\2026\SC5782\RAW_DATA\PVDF\PVDF_PVDF_PDADMAT_4"

Exp = BM26_experiment(path)
q, I = Exp.get_1d_WAXS()
plt.plot(q, I*1e4 + 25, color='#e95e50', linewidth=lines, label='PVDF_PVDF_PDADMAT_4')

# plt.xlim(0.15, 3)

plt.xlabel('q (nm$^{-1}$)', fontname='Arial', fontsize=20)  # ← Markdown для степени
plt.ylabel('I (a.u.)', fontname='Arial', fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=15)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(2)
ax.set_position([0.1, 0.15, 0.75, 0.7])
ax.tick_params(axis="both", which='major', direction="in", width=2, length=4, labelsize=16)
ax.tick_params(axis='both', which='minor', width=2, length=2)

ax.xaxis.set_major_formatter(ScalarFormatter())
# ax.set_xticks([0.2, 1,])
plt.xlim(6, 38)
plt.ylim(-1, 45)
# ax.legend(fontsize=10, frameon=False, fancybox=False, shadow=False)

plt.savefig(r'E:\PVDF_Sergeev\Figures\Fig_WAXS.png', dpi=300, bbox_inches='tight', transparent=True)

# %%
fig, ax = plt.subplots(1,1, figsize=(4,6))
lines = 3
path = r"\\Synology\Data\2026\SC5782\RAW_DATA\PVDF\PVDF_PVDF_1"

Exp = BM26_experiment(path)
q, I = Exp.get_1d_WAXS()
plt.plot(q, I*1e4, color='#f29222', linewidth=lines, label='PVDF_PVDF_1')


path = r"\\Synology\Data\2026\SC5782\RAW_DATA\PVDF\PVDF_PVDF_LiTFSI_2"

Exp = BM26_experiment(path)
q, I = Exp.get_1d_WAXS()
plt.plot(q, I*1e4 + 5 , color='#a1c65d', linewidth=lines, label='PVDF_PVDF_LiTFSI_2')


path = r"\\Synology\Data\2026\SC5782\RAW_DATA\PVDF\PVDF_PVDF_LiTFSI_3"

Exp = BM26_experiment(path)
q, I = Exp.get_1d_WAXS()
plt.plot(q, I*1e4 + 10, color='#0cb2af', linewidth=lines, label='PVDF_PVDF_LiTFSI_3')

path = r"\\Synology\Data\2026\SC5782\RAW_DATA\PVDF\PVDF_PVDF_PDAD_LiTFSZ_5"

Exp = BM26_experiment(path)
q, I = Exp.get_1d_WAXS()
plt.plot(q, I*1e4 + 15, color='#936fac', linewidth=lines, label='PVDF_PVDF_PDAD_LiTFSZ_5')


path = r"\\Synology\Data\2026\SC5782\RAW_DATA\PVDF\PVDF_PVDF_PDAD_6"

Exp = BM26_experiment(path)
q, I = Exp.get_1d_WAXS()
plt.plot(q, I*1e4 + 20, color='#fac723', linewidth=lines, label='PVDF_PVDF_PDAD_6')


path = r"\\Synology\Data\2026\SC5782\RAW_DATA\PVDF\PVDF_PVDF_PDADMAT_4"

Exp = BM26_experiment(path)
q, I = Exp.get_1d_WAXS()
plt.plot(q, I*1e4 + 25, color='#e95e50', linewidth=lines, label='PVDF_PVDF_PDADMAT_4')

# plt.xlim(0.15, 3)

plt.xlabel('q (nm$^{-1}$)', fontname='Arial', fontsize=20)  # ← Markdown для степени
plt.ylabel('I (a.u.)', fontname='Arial', fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=15)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(2)
ax.set_position([0.1, 0.15, 0.75, 0.7])
ax.tick_params(axis="both", which='major', direction="in", width=2, length=4, labelsize=16)
ax.tick_params(axis='both', which='minor', width=2, length=2)

ax.xaxis.set_major_formatter(ScalarFormatter())
# ax.set_xticks([0.2, 1,])
plt.xlim(6, 38)
plt.ylim(-1, 45)
# ax.legend(fontsize=10, frameon=False, fancybox=False, shadow=False)

d_100 = 0.49
d_020 = 0.48
d_110 = 0.44
d_021 = 0.431
d_120 = 0.34
d_111 = 0.32

# plt.axvline(x=2*pi/d_021, color='black')

# %%
fig, ax = plt.subplots(1,1, figsize=(3,6))
lines = 3
path = r"\\Synology\Data\2026\SC5782\RAW_DATA\PVDF\PVDF_PVDF_1"

Exp = BM26_experiment(path)
q, I = Exp.get_1d_SAXS()
plt.loglog(q, I, color='#f29222', linewidth=lines)


path = r"\\Synology\Data\2026\SC5782\RAW_DATA\PVDF\PVDF_PVDF_LiTFSI_2"

Exp = BM26_experiment(path)
q, I = Exp.get_1d_SAXS()
plt.loglog(q, I * 4, color='#a1c65d', linewidth=lines)


path = r"\\Synology\Data\2026\SC5782\RAW_DATA\PVDF\PVDF_PVDF_LiTFSI_3"

Exp = BM26_experiment(path)
q, I = Exp.get_1d_SAXS()
plt.loglog(q, I * 7, color='#0cb2af', linewidth=lines)

path = r"\\Synology\Data\2026\SC5782\RAW_DATA\PVDF\PVDF_PVDF_PDAD_LiTFSZ_5"

Exp = BM26_experiment(path)
q, I = Exp.get_1d_SAXS()
plt.loglog(q, I * 50, color='#936fac', linewidth=lines)


path = r"\\Synology\Data\2026\SC5782\RAW_DATA\PVDF\PVDF_PVDF_PDAD_6"

Exp = BM26_experiment(path)
q, I = Exp.get_1d_SAXS()
plt.loglog(q, I * 100, color='#fac723', linewidth=lines)


path = r"\\Synology\Data\2026\SC5782\RAW_DATA\PVDF\PVDF_PVDF_PDADMAT_4"

Exp = BM26_experiment(path)
q, I = Exp.get_1d_SAXS()
plt.loglog(q, I * 250, color='#e95e50', linewidth=lines)

plt.xlim(0.15, 3)

plt.xlabel('q (nm$^{-1}$)', fontname='Arial', fontsize=20)  # ← Markdown для степени
plt.ylabel('I (a.u.)', fontname='Arial', fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=15)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(2)
ax.set_position([0.1, 0.15, 0.75, 0.7])
ax.tick_params(axis="both", which='major', direction="in", width=2, length=4, labelsize=16)
ax.tick_params(axis='both', which='minor', width=2, length=2)

ax.xaxis.set_major_formatter(ScalarFormatter())
ax.set_xticks([0.2, 1,
              ])

plt.savefig(r'E:\PVDF_Sergeev\Figures\Fig_SAXS.png', dpi=300, bbox_inches='tight', transparent=True)

# %% [markdown]
# # Heating

# %% [markdown]
# #### PVDF_1

# %%
path = r'\\Synology\Data\2026\SC5782\RAW_DATA\PVDF_heating\PVDF_heating_PVDF_1_Heating'

Exp = BM26_experiment(path)
# px.scatter(Exp.get_T_profile())

# %%
fig, ax = plt.subplots(1,1, figsize=(3,6))

q, I = Exp.average_1d([1,2,3,4,5])
plt.loglog(q, I*1e3, color='#1961ae', linewidth=lines)

q, I = Exp.average_1d([122,123,124,125,126])
plt.loglog(q, I*1e2, color='#79c300', linewidth=lines)

q, I = Exp.average_1d([195,196,197,198,199])
plt.loglog(q, I*1e1, color='#61007d', linewidth=lines)

q, I = Exp.average_1d([280,281,282,283,284])
plt.loglog(q, I*2, color='#ef6a00', linewidth=lines)

q, I = Exp.average_1d([370,371,372,373])
plt.loglog(q, I/1e1, color='#f2cd00', linewidth=lines)

# plt.xlim(0.2, 4)
plt.xlim(0.15, 3)

plt.xlabel('q (nm$^{-1}$)', fontname='Arial', fontsize=20)  # ← Markdown для степени
plt.ylabel('I (a.u.)', fontname='Arial', fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=15)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(2)
ax.set_position([0.1, 0.15, 0.75, 0.7])
ax.tick_params(axis="both", which='major', direction="in", width=2, length=4, labelsize=16)
ax.tick_params(axis='both', which='minor', width=2, length=2)

ax.xaxis.set_major_formatter(ScalarFormatter())
ax.set_xticks([0.2, 1,])

plt.savefig(r'E:\PVDF_Sergeev\Figures\Fig_SAXS_Heat_1.png', dpi=300, bbox_inches='tight', transparent=True)

# %%
fig, ax = plt.subplots(1,1, figsize=(4,6))
lines = 3
path = r"\\Synology\Data\2026\SC5782\RAW_DATA\PVDF\PVDF_PVDF_1"

q, I = Exp.get_1d_WAXS(1)
plt.plot(q, I*1e4+8, color='#1961ae', linewidth=lines)

q, I = Exp.get_1d_WAXS(124)
plt.plot(q, I*1e4+6, color='#79c300', linewidth=lines)

q, I = Exp.get_1d_WAXS(197)
plt.plot(q, I*1e4+4, color='#61007d', linewidth=lines)

q, I = Exp.get_1d_WAXS(282)
plt.plot(q, I*1e4+2, color='#ef6a00', linewidth=lines)

q, I = Exp.get_1d_WAXS(370)
plt.plot(q, I*1e4, color='#f2cd00', linewidth=lines)

# plt.xlim(0.15, 3)

plt.xlabel('q (nm$^{-1}$)', fontname='Arial', fontsize=20)  # ← Markdown для степени
plt.ylabel('I (a.u.)', fontname='Arial', fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=15)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(2)
ax.set_position([0.1, 0.15, 0.75, 0.7])
ax.tick_params(axis="both", which='major', direction="in", width=2, length=4, labelsize=16)
ax.tick_params(axis='both', which='minor', width=2, length=2)

ax.xaxis.set_major_formatter(ScalarFormatter())
# ax.set_xticks([0.2, 1,])
plt.xlim(6, 20)
plt.ylim(-1, 15)
# ax.legend(fontsize=10, frameon=False, fancybox=False, shadow=False)
plt.savefig(r'E:\PVDF_Sergeev\Figures\Fig_WAXS_Heat_1.png', dpi=300, bbox_inches='tight', transparent=True)

# %% [markdown]
# #### PVDF 2

# %%
path = r'\\Synology\Data\2026\SC5782\RAW_DATA\PVDF_heating\PVDF_heating_PVDF_2_Heating'

Exp = BM26_experiment(path)
# px.scatter(Exp.get_T_profile())

# %%
fig, ax = plt.subplots(1,1, figsize=(3,6))

q, I = Exp.average_1d([1,2,3,4,5])
plt.loglog(q, I*1e3, color='#1961ae', linewidth=lines)

q, I = Exp.average_1d([71,72,73,74,75])
plt.loglog(q, I*1e2, color='#79c300', linewidth=lines)

q, I = Exp.average_1d([140,141,142,143,144])
plt.loglog(q, I*1e1, color='#61007d', linewidth=lines)

q, I = Exp.average_1d([229,230,231,232,233])
plt.loglog(q, I*2, color='#ef6a00', linewidth=lines)

q, I = Exp.average_1d([318,319,320,321,322])
plt.loglog(q, I/1e1, color='#f2cd00', linewidth=lines)

# plt.xlim(0.2, 4)
plt.xlim(0.15, 3)

plt.xlabel('q (nm$^{-1}$)', fontname='Arial', fontsize=20)  # ← Markdown для степени
plt.ylabel('I (a.u.)', fontname='Arial', fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=15)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(2)
ax.set_position([0.1, 0.15, 0.75, 0.7])
ax.tick_params(axis="both", which='major', direction="in", width=2, length=4, labelsize=16)
ax.tick_params(axis='both', which='minor', width=2, length=2)

ax.xaxis.set_major_formatter(ScalarFormatter())
ax.set_xticks([0.2, 1,])

plt.savefig(r'E:\PVDF_Sergeev\Figures\Fig_SAXS_Heat_2.png', dpi=300, bbox_inches='tight', transparent=True)

# %%
fig, ax = plt.subplots(1,1, figsize=(4,6))
lines = 3
path = r"\\Synology\Data\2026\SC5782\RAW_DATA\PVDF\PVDF_PVDF_1"

q, I = Exp.get_1d_WAXS(1)
plt.plot(q, I*1e4+11, color='#1961ae', linewidth=lines)

q, I = Exp.get_1d_WAXS(72)
plt.plot(q, I*1e4+6, color='#79c300', linewidth=lines)

q, I = Exp.get_1d_WAXS(140)
plt.plot(q, I*1e4+4, color='#61007d', linewidth=lines)

q, I = Exp.get_1d_WAXS(230)
plt.plot(q, I*1e4+2, color='#ef6a00', linewidth=lines)

q, I = Exp.get_1d_WAXS(320)
plt.plot(q, I*1e4, color='#f2cd00', linewidth=lines)

# plt.xlim(0.15, 3)

plt.xlabel('q (nm$^{-1}$)', fontname='Arial', fontsize=20)  # ← Markdown для степени
plt.ylabel('I (a.u.)', fontname='Arial', fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=15)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(2)
ax.set_position([0.1, 0.15, 0.75, 0.7])
ax.tick_params(axis="both", which='major', direction="in", width=2, length=4, labelsize=16)
ax.tick_params(axis='both', which='minor', width=2, length=2)

ax.xaxis.set_major_formatter(ScalarFormatter())
# ax.set_xticks([0.2, 1,])
plt.xlim(6, 20)
plt.ylim(-1, 15)
# ax.legend(fontsize=10, frameon=False, fancybox=False, shadow=False)
plt.savefig(r'E:\PVDF_Sergeev\Figures\Fig_WAXS_Heat_2.png', dpi=300, bbox_inches='tight', transparent=True)

# %% [markdown]
# #### PVDF 3

# %%
path = r'\\Synology\Data\2026\SC5782\RAW_DATA\PVDF_heating\PVDF_heating_PVDF_3_Heating'

Exp = BM26_experiment(path)
# px.scatter(Exp.get_T_profile())

# %%
fig, ax = plt.subplots(1,1, figsize=(3,6))

q, I = Exp.average_1d([1,2,3,4,5])
plt.loglog(q, I*1e3, color='#1961ae', linewidth=lines)

q, I = Exp.average_1d([87,88,89,90,91])
plt.loglog(q, I*1e2, color='#79c300', linewidth=lines)

q, I = Exp.average_1d([155,156,157,158,159])
plt.loglog(q, I*1e1, color='#61007d', linewidth=lines)

q, I = Exp.average_1d([244,245,246,247,248])
plt.loglog(q, I*2, color='#ef6a00', linewidth=lines)

q, I = Exp.average_1d([334,335,336,337,339])
plt.loglog(q, I/1e1, color='#f2cd00', linewidth=lines)

# plt.xlim(0.2, 4)
plt.xlim(0.15, 3)

plt.xlabel('q (nm$^{-1}$)', fontname='Arial', fontsize=20)  # ← Markdown для степени
plt.ylabel('I (a.u.)', fontname='Arial', fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=15)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(2)
ax.set_position([0.1, 0.15, 0.75, 0.7])
ax.tick_params(axis="both", which='major', direction="in", width=2, length=4, labelsize=16)
ax.tick_params(axis='both', which='minor', width=2, length=2)

ax.xaxis.set_major_formatter(ScalarFormatter())
ax.set_xticks([0.2, 1,])

plt.savefig(r'E:\PVDF_Sergeev\Figures\Fig_SAXS_Heat_3.png', dpi=300, bbox_inches='tight', transparent=True)

# %%
fig, ax = plt.subplots(1,1, figsize=(4,6))
lines = 3
q, I = Exp.get_1d_WAXS(1)
plt.plot(q, I*1e4+6, color='#1961ae', linewidth=lines)

q, I = Exp.get_1d_WAXS(89)
plt.plot(q, I*1e4+4, color='#79c300', linewidth=lines)

q, I = Exp.get_1d_WAXS(157)
plt.plot(q, I*1e4+2, color='#61007d', linewidth=lines)

q, I = Exp.get_1d_WAXS(247)
plt.plot(q, I*1e4+1, color='#ef6a00', linewidth=lines)

q, I = Exp.get_1d_WAXS(336)
plt.plot(q, I*1e4, color='#f2cd00', linewidth=lines)

# plt.xlim(0.15, 3)

plt.xlabel('q (nm$^{-1}$)', fontname='Arial', fontsize=20)  # ← Markdown для степени
plt.ylabel('I (a.u.)', fontname='Arial', fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=15)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(2)
ax.set_position([0.1, 0.15, 0.75, 0.7])
ax.tick_params(axis="both", which='major', direction="in", width=2, length=4, labelsize=16)
ax.tick_params(axis='both', which='minor', width=2, length=2)

ax.xaxis.set_major_formatter(ScalarFormatter())
# ax.set_xticks([0.2, 1,])
plt.xlim(8, 20)
plt.ylim(-0.5, 10)
# ax.legend(fontsize=10, frameon=False, fancybox=False, shadow=False)
plt.savefig(r'E:\PVDF_Sergeev\Figures\Fig_WAXS_Heat_3.png', dpi=300, bbox_inches='tight', transparent=True)

# %% [markdown]
# #### PVDF 4

# %%
path = r'\\Synology\Data\2026\SC5782\RAW_DATA\PVDF_heating\PVDF_heating_PVDF_4_Heating'

Exp = BM26_experiment(path)
# px.scatter(Exp.get_T_profile())

# %%
fig, ax = plt.subplots(1,1, figsize=(3,6))

q, I = Exp.average_1d([1,2,3,4,5])
plt.loglog(q, I*1e3, color='#1961ae', linewidth=lines)

q, I = Exp.average_1d([60,61,62,63,64])
plt.loglog(q, I*1e2, color='#79c300', linewidth=lines)

q, I = Exp.average_1d([127, 128, 129, 130, 131])
plt.loglog(q, I*1e1, color='#61007d', linewidth=lines)

q, I = Exp.average_1d([215,216,217,218,219])
plt.loglog(q, I*2, color='#ef6a00', linewidth=lines)

q, I = Exp.average_1d([302,303,304,305,306])
plt.loglog(q, I/1e1, color='#f2cd00', linewidth=lines)

# plt.xlim(0.2, 4)
plt.xlim(0.15, 3)

plt.xlabel('q (nm$^{-1}$)', fontname='Arial', fontsize=20)  # ← Markdown для степени
plt.ylabel('I (a.u.)', fontname='Arial', fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=15)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(2)
ax.set_position([0.1, 0.15, 0.75, 0.7])
ax.tick_params(axis="both", which='major', direction="in", width=2, length=4, labelsize=16)
ax.tick_params(axis='both', which='minor', width=2, length=2)

ax.xaxis.set_major_formatter(ScalarFormatter())
ax.set_xticks([0.2, 1,])

plt.savefig(r'E:\PVDF_Sergeev\Figures\Fig_SAXS_Heat_4.png', dpi=300, bbox_inches='tight', transparent=True)

# %%
fig, ax = plt.subplots(1,1, figsize=(4,6))
lines = 3
q, I = Exp.get_1d_WAXS(1)
plt.plot(q, I*1e4+8, color='#1961ae', linewidth=lines)

q, I = Exp.get_1d_WAXS(62)
plt.plot(q, I*1e4+6, color='#79c300', linewidth=lines)

q, I = Exp.get_1d_WAXS(129)
plt.plot(q, I*1e4+4, color='#61007d', linewidth=lines)

q, I = Exp.get_1d_WAXS(220)
plt.plot(q, I*1e4+2, color='#ef6a00', linewidth=lines)

q, I = Exp.get_1d_WAXS(308)
plt.plot(q, I*1e4, color='#f2cd00', linewidth=lines)

# plt.xlim(0.15, 3)

plt.xlabel('q (nm$^{-1}$)', fontname='Arial', fontsize=20)  # ← Markdown для степени
plt.ylabel('I (a.u.)', fontname='Arial', fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=15)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(2)
ax.set_position([0.1, 0.15, 0.75, 0.7])
ax.tick_params(axis="both", which='major', direction="in", width=2, length=4, labelsize=16)
ax.tick_params(axis='both', which='minor', width=2, length=2)

ax.xaxis.set_major_formatter(ScalarFormatter())
# ax.set_xticks([0.2, 1,])
plt.xlim(8, 20)
plt.ylim(-0.5, 20)
# ax.legend(fontsize=10, frameon=False, fancybox=False, shadow=False)
plt.savefig(r'E:\PVDF_Sergeev\Figures\Fig_WAXS_Heat_4.png', dpi=300, bbox_inches='tight', transparent=True)

# %% [markdown]
# #### PVDF 5

# %%
path = r'\\Synology\Data\2026\SC5782\RAW_DATA\PVDF_heating\PVDF_heating_PVDF_5_Heating'

Exp = BM26_experiment(path)
# px.scatter(Exp.get_T_profile())

# %%
fig, ax = plt.subplots(1,1, figsize=(3,6))

q, I = Exp.average_1d([1,2,3,4,5])
plt.loglog(q, I*1e3, color='#1961ae', linewidth=lines)

q, I = Exp.average_1d([60,61,62,63,64])
plt.loglog(q, I*1e2, color='#79c300', linewidth=lines)

q, I = Exp.average_1d([127, 128, 129, 130, 131])
plt.loglog(q, I*1e1, color='#61007d', linewidth=lines)

q, I = Exp.average_1d([215,216,217,218,219])
plt.loglog(q, I*2, color='#ef6a00', linewidth=lines)

q, I = Exp.average_1d([302,303,304,305,306])
plt.loglog(q, I/1e1, color='#f2cd00', linewidth=lines)

# plt.xlim(0.2, 4)
plt.xlim(0.15, 3)

plt.xlabel('q (nm$^{-1}$)', fontname='Arial', fontsize=20)  # ← Markdown для степени
plt.ylabel('I (a.u.)', fontname='Arial', fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=15)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(2)
ax.set_position([0.1, 0.15, 0.75, 0.7])
ax.tick_params(axis="both", which='major', direction="in", width=2, length=4, labelsize=16)
ax.tick_params(axis='both', which='minor', width=2, length=2)

ax.xaxis.set_major_formatter(ScalarFormatter())
ax.set_xticks([0.2, 1,])

plt.savefig(r'E:\PVDF_Sergeev\Figures\Fig_SAXS_Heat_5.png', dpi=300, bbox_inches='tight', transparent=True)

# %%
fig, ax = plt.subplots(1,1, figsize=(4,6))
lines = 3
q, I = Exp.get_1d_WAXS(1)
plt.plot(q, I*1e4+8, color='#1961ae', linewidth=lines)

q, I = Exp.get_1d_WAXS(62)
plt.plot(q, I*1e4+6, color='#79c300', linewidth=lines)

q, I = Exp.get_1d_WAXS(129)
plt.plot(q, I*1e4+4, color='#61007d', linewidth=lines)

q, I = Exp.get_1d_WAXS(220)
plt.plot(q, I*1e4+2, color='#ef6a00', linewidth=lines)

q, I = Exp.get_1d_WAXS(308)
plt.plot(q, I*1e4, color='#f2cd00', linewidth=lines)

# plt.xlim(0.15, 3)

plt.xlabel('q (nm$^{-1}$)', fontname='Arial', fontsize=20)  # ← Markdown для степени
plt.ylabel('I (a.u.)', fontname='Arial', fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=15)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(2)
ax.set_position([0.1, 0.15, 0.75, 0.7])
ax.tick_params(axis="both", which='major', direction="in", width=2, length=4, labelsize=16)
ax.tick_params(axis='both', which='minor', width=2, length=2)

ax.xaxis.set_major_formatter(ScalarFormatter())
# ax.set_xticks([0.2, 1,])
plt.xlim(8, 19)
plt.ylim(-0.5, 19)
# ax.legend(fontsize=10, frameon=False, fancybox=False, shadow=False)
plt.savefig(r'E:\PVDF_Sergeev\Figures\Fig_WAXS_Heat_5.png', dpi=300, bbox_inches='tight', transparent=True)

# %% [markdown]
# #### PVDF 6

# %%
path = r'\\Synology\Data\2026\SC5782\RAW_DATA\PVDF_heating\PVDF_heating_PVDF_6_Heating'

Exp = BM26_experiment(path)
# px.scatter(Exp.get_T_profile())

# %%
fig, ax = plt.subplots(1,1, figsize=(3,6))

q, I = Exp.average_1d([1,2,3,4,5])
plt.loglog(q, I*1e3, color='#1961ae', linewidth=lines)

q, I = Exp.average_1d([70,71,72,73,74])
plt.loglog(q, I*1e2, color='#79c300', linewidth=lines)

q, I = Exp.average_1d([140, 141, 142, 143, 144])
plt.loglog(q, I*1e1, color='#61007d', linewidth=lines)

q, I = Exp.average_1d([229, 230, 231, 232, 234])
plt.loglog(q, I*2, color='#ef6a00', linewidth=lines)

q, I = Exp.average_1d([302,303,304,305,306])
plt.loglog(q, I/2e1, color='#f2cd00', linewidth=lines)

# plt.xlim(0.2, 4)
plt.xlim(0.15, 3)

plt.xlabel('q (nm$^{-1}$)', fontname='Arial', fontsize=20)  # ← Markdown для степени
plt.ylabel('I (a.u.)', fontname='Arial', fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=15)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(2)
ax.set_position([0.1, 0.15, 0.75, 0.7])
ax.tick_params(axis="both", which='major', direction="in", width=2, length=4, labelsize=16)
ax.tick_params(axis='both', which='minor', width=2, length=2)

ax.xaxis.set_major_formatter(ScalarFormatter())
ax.set_xticks([0.2, 1,])

plt.savefig(r'E:\PVDF_Sergeev\Figures\Fig_SAXS_Heat_6.png', dpi=300, bbox_inches='tight', transparent=True)

# %%
fig, ax = plt.subplots(1,1, figsize=(4,6))
lines = 3
q, I = Exp.get_1d_WAXS(1)
plt.plot(q, I*1e4+16, color='#1961ae', linewidth=lines)

q, I = Exp.get_1d_WAXS(72)
plt.plot(q, I*1e4+12, color='#79c300', linewidth=lines)

q, I = Exp.get_1d_WAXS(142)
plt.plot(q, I*1e4+8, color='#61007d', linewidth=lines)

q, I = Exp.get_1d_WAXS(231)
plt.plot(q, I*1e4+4, color='#ef6a00', linewidth=lines)

q, I = Exp.get_1d_WAXS(304)
plt.plot(q, I*1e4, color='#f2cd00', linewidth=lines)

# plt.xlim(0.15, 3)

plt.xlabel('q (nm$^{-1}$)', fontname='Arial', fontsize=20)  # ← Markdown для степени
plt.ylabel('I (a.u.)', fontname='Arial', fontsize=20)
ax.tick_params(axis='both', which='major', labelsize=15)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(2)
ax.set_position([0.1, 0.15, 0.75, 0.7])
ax.tick_params(axis="both", which='major', direction="in", width=2, length=4, labelsize=16)
ax.tick_params(axis='both', which='minor', width=2, length=2)

ax.xaxis.set_major_formatter(ScalarFormatter())
# ax.set_xticks([0.2, 1,])
plt.xlim(8, 19)
plt.ylim(-0.5, 26)
# ax.legend(fontsize=10, frameon=False, fancybox=False, shadow=False)
plt.savefig(r'E:\PVDF_Sergeev\Figures\Fig_WAXS_Heat_6.png', dpi=300, bbox_inches='tight', transparent=True)
