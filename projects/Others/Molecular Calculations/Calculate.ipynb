# %%
rho_pnipam = 1.1
rho_peg = 1.1
M_pnipam = 113.6
M_peg = 44
N_A = 6.02e23

V1_pnipam = M_pnipam / rho_pnipam / N_A * 1e21
# print(V1_pnipam)
V1_peg = M_peg / rho_peg / N_A * 1e21
# print(V1_peg)

n_bb = 290
n_sc = 19

N_peg = n_bb * n_sc
V_peg = N_peg * V1_peg

0.06 * V_peg / V1_pnipam / 2
# Out:
# 64.02464788732395

# %%
V1_peg
# Out:
# 0.06493506493506493
