# %%
import numpy as np
pi = np.pi
N_a = 6.022 * 1e23

# %% [markdown]
# # N_g = 1

# %%
# ng = 1
rho_PDMS = 1
M_PDMS = 74
V_PDMS = M_PDMS/rho_PDMS * 14 / N_a * 1e21

rho_PMMA = 1.18
M_PMMA = 112
V_PMMA = M_PMMA/rho_PMMA * 1 / N_a * 1e21

d1 = 3.5
R2 = d1 / 2
R1 = R2 * np.sqrt(V_PMMA/ (V_PMMA + V_PDMS))
h = V_PMMA / pi / R1 **2
h
# Out:
# np.float64(0.19519259632221114)

# %%
R1 / np.sqrt(V_PMMA/ (V_PMMA + V_PDMS))
# Out:
# np.float64(1.75)

# %% [markdown]
# # N_g = 7

# %%
rho_PDMS = 1
M_PDMS = 74
V_PDMS = M_PDMS/rho_PDMS * 14

rho_PMMA = 1.18
M_PMMA = 100
V_PMMA = M_PMMA/rho_PMMA * 7

R3 = np.sqrt(V_PMMA / pi / h)
R4 = R3 / np.sqrt(V_PMMA/ (V_PMMA + V_PDMS))

# %%
R4
# Out:
# np.float64(2.1099609003266826)

# %%
R
