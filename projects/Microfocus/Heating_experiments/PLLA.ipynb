# %% [markdown]
# # Set up

# %%
# %run ../../../setup_workspace.py # ../ means level up
# Out:
# ✓ Workspace ready

# %% [markdown]
# # Data

# %%
path = r"\\Synology\Data\2025\SC5671-ID13\RAW_DATA\COPO-500-STR75\COPO-500-STR75_drop_TC180cold_run3\scan00001\eiger\COPO-500-STR75_drop_TC180cold_run3_00001_data_000000.h5"
file = h5py.File(path, 'r')
#file['entry_0000']['PyFAI']['result_ave']['data'][:]
df = file['entry_0000']['measurement']['data'][()]

# %%
img = df[0]
from pyFAI.gui import jupyter
jupyter.plot2d(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 3
#       1 img = df[0]
#       2 from pyFAI.gui import jupyter
# ----> 3 jupyter.plot2d(img)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pyFAI\gui\jupyter\_plot.py:144, in plot2d(result, calibrant, label, ax)
#     134 def plot2d(result, calibrant=None, label=None, ax=None):
#     135     """Display the caked image in the jupyter notebook
#     136
#     137     :param result: instance of Integrate2dResult
#    (...)    142     :return: Matplotlib subplot
#     143     """
# --> 144     img = result.intensity
#     145     pos_rad = result.radial
#     146     pos_azim = result.azimuthal
#
# AttributeError: 'numpy.ndarray' object has no attribute 'intensity'
