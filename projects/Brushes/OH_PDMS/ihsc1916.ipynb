# %%
# %run ../../../setup_workspace.py
pi = np.pi

# %%
path = r'\\Synology\Data\2025\ihsc1916\20251129\RAW_DATA\Bott_PDMS_bis\Bott_PDMS_bis_PDMS_BNMA_NG4_melt'

Exp = BM26_experiment(path)

# %%
px.scatter(Exp.get_T_profile())
# Out:
# Found 10 EDF files in SAXS

# %%
plt.figure(figsize=(4,4))

q, I = Exp.average_1d(range(5))

plt.loglog(q, I, label='22C')

q, I = Exp.average_1d([6,7])

plt.loglog(q, I, label='55C')

q, I = Exp.average_1d([8,9])

plt.loglog(q, I, label='75C')

plt.legend()
plt.xlim(0.08, 4)
plt.ylim(2, 2e2)
# Out:
# (2, 200.0)
