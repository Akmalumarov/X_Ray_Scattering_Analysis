# %%
# %run ../../../setup_workspace.py # ../ means level up

# %%
Exp1 = BM26_experiment(r'\\Synology\Data\2026\SC5735\RAW_DATA\PCL_PEG_20percbrush_water\PCL_PEG_20percbrush_water_PCL_PEG_20perc_25C_isoth')

Exp1.get_T_profile()
# Out:
# Found 93 EDF files in SAXS
# array([77.2, 72.6, 67.7, 62.7, 57.7, 52.7, 47.7, 42.8, 37.9, 32.8, 27.9,
#        24.9, 25. , 25. , 25. , 25. , 25. , 25. , 25. , 25. , 25. , 25. ,
#        25. , 25. , 25. , 25. , 25. , 24.9, 25. , 25. , 25. , 25. , 25. ,
#        25. , 25. , 25. , 25. , 25. , 25. , 25. , 25. , 25. , 25. , 25. ,
#        25. , 25. , 25. , 25. , 25. , 25. , 25. , 25. , 25. , 25. , 25. ,
#        25. , 25. , 25. , 25. , 25. , 25. , 25. , 25. , 25. , 25. , 25. ,
#        25. , 25. , 25. , 25. , 25. , 25. , 25. , 25. , 25. , 25. , 25. ,
#        25. , 25. , 25. , 25. , 25. , 25. , 25. , 25. , 25. , 25. , 25. ,
#        25. , 25. , 25. , 25. , 25. ])

# %%
plt.plot(Exp1.get_Time_profile(), Exp1.get_T_profile())

plt.xlim(0, 500)
# Out:
# Found 93 EDF files in SAXS
# (0.0, 500.0)
